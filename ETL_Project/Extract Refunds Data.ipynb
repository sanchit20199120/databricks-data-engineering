-- %%
Create connection sql_gizmobox_db_conn 
TYPE sqlserver
OPTIONS (
  host "gizmobox-serveretl.database.windows.net",
  port "1433",
  user "gizmobozadmin",
  password "20Sep199120@"
);

-- %%
CREATE FOREIGN CATALOG IF NOT EXISTS sql_gizmobox_db_catalog_sqlserver
USING CONNECTION sql_gizmobox_db_conn
OPTIONS (database "gizmobox-db");

-- %%
SHOW CATALOGS;

-- %%
USE CATALOG sql_gizmobox_db_catalog_sqlserver;

-- %%
SHOW SCHEMAS;

-- %%
USE SCHEMA dbo;

-- %%
select * from refunds;
