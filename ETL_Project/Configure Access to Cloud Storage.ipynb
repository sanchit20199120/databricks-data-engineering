-- %%
%fs ls 'abfss://gizmobox@deacourseextlakehouse.dfs.core.windows.net/'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_gizmobox 
    URL 'abfss://gizmobox@deacourseextlakehouse.dfs.core.windows.net/'
     WITH (CREDENTIAL dea_course_ext_sc)
     COMMENT 'External Location for GizmoBox Project';
