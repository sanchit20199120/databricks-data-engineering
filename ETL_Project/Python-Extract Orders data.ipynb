# %%
orders_df = spark.read.format('text').load('/Volumes/gizmobox/landing/operational_data/orders/').select('*','_metadata.file_path','_metadata.file_modification_time')
display(orders_df)

# %%
orders_df.writeTo('gizmobox.bronze.py_orders').createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_orders;
