# %%
membership_df = spark.read.format('binaryFile').load('/Volumes/gizmobox/landing/operational_data/memberships/*')
display(membership_df)

# %%
membership_df.writeTo('gizmobox.bronze.py_memberships').createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.v_memberships;

# %%
# %sql
select * from gizmobox.bronze.v_memberships;
