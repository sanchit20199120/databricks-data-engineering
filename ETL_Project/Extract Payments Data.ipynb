-- %%
%fs ls 'abfss://gizmobox@deacourseextlakehouse.dfs.core.windows.net/landing/external_data/payments'

-- %%
CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments (
  payment_id INTEGER,
  order_id INTEGER,
  payment_timestamp TIMESTAMP,
  payment_status INTEGER,
  payment_method STRING
)
USING CSV
OPTIONS (header = "true",
         delimiter = ",")
LOCATION 'abfss://gizmobox@deacourseextlakehouse.dfs.core.windows.net/landing/external_data/payments'

-- %%
select * from gizmobox.bronze.payments;

-- %%
DESCRIBE EXTENDED gizmobox.bronze.payments;

-- %%
DESCRIBE HISTORY gizmobox.bronze.payments;

-- %%
REFRESH TABLE gizmobox.bronze.payments;
