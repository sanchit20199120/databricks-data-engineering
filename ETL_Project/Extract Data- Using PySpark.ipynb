# %%
customer_df = spark.sql('''select * 
                        from gizmobox.bronze.v_customers ''')
#customer_df.show()
display(customer_df)

# %%
orders_df =spark.table('gizmobox.bronze.v_orders')
display(orders_df)

# %%
addresses_df =  (
    spark.read.format('csv').
    option('header','true').
    option('delimiter','\t').
    load('/Volumes/gizmobox/landing/operational_data/addresses/')
)
display(addresses_df)
