# %%
refund_df =( 
  spark.table('sql_gizmobox_db_catalog_sqlserver.dbo.refunds')
   )

display(refunds_df)

# %%
refunds_df_jdbc =( 
  spark.read.format('jdbc')
  .option('url','jdbc:sqlserver://gizmobox-serveretl.database.windows.net:1433;database=gizmobox-db')
  .option('dbtable','refunds')
  .option('user','gizmobozadmin')
  .option('password','20Sep199120@')
  .load()
   )

display(refunds_df_jdbc)

# %%
refunds_df_jdbc.writeTo('gizmobox.bronze.py_refunds').createOrReplace()

# %%
# %sql

select * from gizmobox.bronze.py_refunds;
